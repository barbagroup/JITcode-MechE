# %% [markdown]
# ###New idea
#
# wind speed data
#
# several data sets
#
# maybe filename gives indication of units used? (m/s vs knots vs mph)
#
# goal is to find best site for turbine (overall good wind speed, windy the most without exceeding maximum allowable wind speed)
#
# first, create functions to convert from mph -> m/s and knots -> m/s
#
# then... what?
#
# using glob to find files in winddata directory
# send filename to function that contains:
# *  if statement to check if filename ends in kt, mph or ms?
# *  loads data file,
# *  converts to ms,
# *  saves new data to new file with appropriate suffix
#
#
# suggest that students compare two datasets in particular, plot both of them along with lines for max wind power (determined by turbine data sheet) as well as plotting the average windspeed for both datasets, so plot will have
# *  max wind speed line
# *  data set 1
# *  data set 1 avg
# *  data set 2
# *  data set 2 avg

# %% [markdown]
# #JITcode 1, lesson 2

# %% [markdown]
# The first *Just-in-Time (JIT) module* for teaching computing to engineers, in context, lays the foundations for building computational skills.
#
# Did you complete [lesson 1](http://nbviewer.ipython.org/github/barbagroup/JITcode-MechE/blob/master/lessons/01_Lesson01_ReadAndPlot.ipynb)? If so, you now know how to read a data file, make some plots to study the data, and do some basic data analysis. These are all very useful skills! You will likely soon have a lab report to do where you can apply them.
#
# What next? There are so many choices! Let's do something creative. In this lesson, you will learn to *create your own functions*!
#
# What can you do with functions that you create? Anything, really. Watch this funky video for an introducton to creating functions.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('gTwU8JPgu5E')
# Out:
#         <iframe
#             width="400"
#             height=300"
#             src="https://www.youtube.com/embed/gTwU8JPgu5E"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ##Context -- Turbine Placement
#
# ###Multiple data sets
#
# In the first module, we investigated global surface temperature anomalies and discovered a pretty distinct upward trend in the data.  All of our data in that module was contained in one file, but it will very often be the case that we have multiple files to work with.
#
# In the resources folder, there's a subdirectory called "winddata" that contains a number of files that record the average windspeed over the course of _ days in several locations.  Our goal is to determine which of these locations is the best candidate for our wind turbine.

# %% [markdown]
# ##Placement criteria
#
# There are a lot of factors that go into choosing a good turbine site, even after a bunch of wind data has been collected.  Here are the factors we have to keep in mind:
#
# ####  Average site wind speed
# The higher the average wind speed, the more power we can extract.
#
# ####Maximum wind speed
# Turbine blades have certain limits and if the wind is too strong or too unpredictable, it can damage the whole turbine assembly.
#
# ##Potential issues
#
# Our data was collected at several sites by a few different contractors and has, unfortunately, been delivered in several different unit systems.  Our data files are either in meters-per-second (which we want), in miles-per-hour (which we don't want) or in knots (which we also don't want).
#
# To get all of our data in m/s, we're going to need the appropriate conversion factors.
#
# $$1 \rm{mph} = .447 \rm{m/s}$$
# $$1 \rm{knot} = .514 \rm{m/s}$$
#
# if we want to convert things back into mph or knots, we can use
#
# $$1 \rm{m/s} = 2.236 \rm{mph}$$
# $$1 \rm{m/s} = 1.943 \rm{knots}$$

# %% [markdown]
# ## Create a function
# Can we create a function that will make the conversion from miles per hour to meters per second? Sure! First, decide what you will call it ... how about `MilesPerHourtoMetersPerSecond`?  That's a bit long.  `mph2ms`?  That's a little bit hard to parse -- maybe we can make it a little easier to read.  Let's try `mph_to_ms`.
#
# Next, we decide what the input and output of our function will be, and we use the `def` command to create it. The input goes in parenthesis next to the function name, and the definition line has to end with a colon:

# %%
def mph_to_ms(speed):
    return speed*.447

# %%
def knot_to_ms(speed):
    return speed*.514

# %% [markdown]
# ##Working with multiple files

# %%
import numpy
import glob

# %%
filenames = glob.glob('./resources/winddata/*.csv')
print filenames
# Out:
# ['./resources/winddata/site2_ms.csv', './resources/winddata/site1_mph.csv', './resources/winddata/site3_knot.csv']

# %% [markdown]
# Explain if statements here
#
# going to use `if 'ms' in fname: do conversion'
#
# function checks filetype, the loads file and sends it to converter

# %%
def checkandconvert(fname):
    if 'mph' in fname:
        speeddata = numpy.loadtxt(fname,delimiter=',')
        return mph_to_ms(speeddata)
    
    if 'knot' in fname:
        speeddata = numpy.loadtxt(fname,delimiter=',')
        return knot_to_ms(speeddata)
    
    if 'ms' in fname:
        speeddata = numpy.loadtxt(fname,delimiter=',')
        return speeddata

# %%
ppp = checkandconvert(x[1])

# %%
ppp
# Out:
# array([ 10.51839785,   9.59212496,   4.68552427,  11.36113103,
#          4.86583805,   1.76179804,  12.40924525,   5.93818072,
#          3.86650022,   6.39847545,   3.63705554,   1.20234722,
#          9.91814084,   2.81989684,   4.10976486,   0.47101449,
#          1.80031897,  11.45405731,  11.01837828,   4.30045795,
#         11.8521425 ,   2.97821341,   5.1403272 ,  10.88039192,
#          0.97766681,   1.19307881,   0.8508637 ,   4.54330995,
#          1.29879371,  11.57422933,   7.67046001,   8.71197712,
#          0.99214437,   1.32605   ,  11.13973096,   9.11437034,
#          9.94023026,   5.78087016,   5.44236862,   0.40733266,
#         12.34769936,   1.82787494,   0.84599876,  11.87873108,
#          0.04893761,   3.16806028,   1.16319274,  13.30620852,
#         12.14221225,  10.07063708,   0.72700112,  12.15222116,
#          5.08469154,  10.85549752,   6.20067911,   8.24186502,
#          6.04632269,   6.20529334,   1.89525872,   1.08486623,
#         12.48924387,  11.88583437,   1.03048431,   0.11284429,
#          5.51416266,   9.3221405 ,  12.71226547,  12.1445791 ,
#          9.46855544,   3.78070641,   4.00161903,   3.04010426,
#          7.93925373,   4.18263708,  13.34258399,   2.44823367,
#          3.3999108 ,  10.68577392,   5.4412426 ,   9.21158712,
#          0.05112987,  11.62492045,  13.28157408,  12.86700093,
#         11.74628217,   2.6684226 ,   1.12981102,   0.20959435,
#          7.71450954,   9.26148004,  10.06633355,  12.57705972,
#          0.80633301,   7.86006688,   8.39781928,  11.57853734,
#          9.14514745,   3.65320794,   7.06050666,   4.46746097,
#          9.76904462,  12.2292844 ,   0.01504273,   3.28223443,
#          7.50916801,   1.99753329,   6.90671288,   3.99861201,
#         10.53105971,  11.00973732,   4.3775118 ,  12.47501752,
#          8.23418162,   6.82060374,   9.15425647,   5.654926  ,
#         12.63962815,   1.73527634,   6.43202915,   5.13718031,
#          3.57825752,   3.41372007,   9.11301791,  11.86212035,
#          2.67393982,   0.50347554,   8.7736151 ,   0.26826297,
#          6.86376264,  13.04981311,   9.29319572,   3.51086656,
#          6.00643836,   3.04034957,  11.04865554,  12.29266478,
#          2.82654569,   3.23081219,   4.68142223,   6.33057084,
#          7.12220921,   9.68132074,   7.94837308,  10.04138052,
#          8.39351707,   5.05619298,  10.08374211,   4.63986296,
#          2.32318405,   9.47646039,  11.88371967,   7.3703768 ,
#          0.68962522,   7.02464565,   5.85381149,   6.01330385,
#          0.82833664,   1.922068  ,   9.10676043,   5.10684146,
#          7.7967784 ,   1.32313368,   3.48551232,   3.82544381,
#          3.17698217,   1.87863287,  13.18031336,   6.3419829 ,
#         11.61454575,   6.98854498,   1.52917887,   5.03827392,
#         13.3153644 ,   5.82061882,  11.7630617 ,  11.82169205,
#         11.72892901,   2.41110011,  12.86640676,  10.26215633,
#          2.96135856,   1.41911276,   0.70511708,   3.2266889 ,
#          7.19442576,  10.39116199,   3.4803529 ,   3.48560083,
#          5.74277323,  13.26638087,   8.25197144,   3.4847816 ,
#          7.4022516 ,   2.23568757,   1.82558993,   7.52347819,
#          7.37114375,   2.18224507,   8.80936837,   4.53964081,
#          5.93263372,   2.83452108,   6.56899562,   2.55521208,
#          5.17420865,   2.44950811,   7.36133815,   4.95838794,
#          6.21492533,  10.83113607,   1.31073944,   9.14266552,
#         12.04877886,  13.37907082,   1.53253287,   4.48703945,
#         11.78567953,  12.37486286,   6.26028138,   7.29404015,
#          0.83457617,   3.4029449 ,   8.30009896,   0.62624531,
#          9.52597771,   0.61691637,   8.67368024,   8.9378064 ,
#          9.63507309,   9.66580203,   0.2791113 ,   6.39882831,
#          1.25697361,  12.79371879,   6.94985169,  10.98289021,
#          9.4534462 ,   2.06798197,   0.12635045,   7.9689457 ,
#          2.81605067,   6.61680457,   3.24610884,  11.31406216,
#          7.31111893,  12.03748785,  12.43360069,   9.88957829,
#         10.46646465,  12.33836023,  12.10564817,   8.50347788,
#          3.18890372,  11.39253886,  10.35726789,   3.69902698,
#          1.55138651,   5.48933135,   9.23207669,  10.71500181,
#         10.9985887 ,   7.27740105,   7.01604882,   7.41724889,
#         11.60048082,   9.309163  ,   8.44632769,   6.35160108,
#         10.21148782,   1.90540585,  11.70761876,   5.41363539,
#          8.33672873,   5.36359285,  11.80965454,  11.01457797,
#          2.54096847,   8.70246469,  10.87228861,   5.73493585,
#         12.60759454,   1.54363035,   0.81643418,  10.18299179,
#          5.95367363,  13.15994138,  10.51940188,   7.62596261,
#          2.00752218,  12.46180365,  10.36375175,  12.51340865,
#          1.17344657,   7.48349564,   1.08181898,  10.05860259,
#          5.23605226,   3.57105531,   3.0804449 ,   7.46261013,
#          9.77690814,   7.90515382,   4.28524405,   9.66867404,
#          1.32672897,  10.11199667,   8.70921659,   2.36319736,
#          5.17158199,   9.64090919,   1.45366672,   4.87276957,
#         12.257332  ,  10.87388442,   6.45932877,   5.36244081,
#         11.81530873,  10.17115166,   2.99922875,   4.09190213,
#          2.55310761,   5.47414828,   6.29455623,   6.14394856,
#          9.74851801,  12.13714668,   8.30282669,   6.78021731,
#          9.73510311,   8.79085768,   5.62104386,   4.08398651,
#         10.17077263,   4.73092456,   4.98244425,   9.66141467,
#          5.71642837,   2.34457796,  11.53353484,  13.32506172,
#         11.39530014,  11.01604887,   3.34030268,   1.26668735,
#         11.8433752 ,   0.67402662,   4.35361705,   7.8785462 ,
#          4.70033969,   3.60772193,   7.13902176,   1.07931086,
#          7.48079637,  12.83546247,  13.19372864,   4.07640627,
#          4.21365486,   8.79936937,   9.74591008,   3.28016331,
#         10.23156407,   4.84830509,   9.57775465,  10.52992183,
#          9.46514394,   4.61709613,   4.04490858,   6.88660802,
#         13.38619425,   4.99337537,   0.57616021,   1.57658222,
#         10.91663714,   4.40435172,   9.69239249,   4.81164239,
#         11.56405445,  10.48145348,   8.15035022,   7.59223703,
#          9.64188067,  10.49963548,   4.02970599,  10.17766975,
#          2.21793935,   8.44732196,   2.42377623,   3.88698395,
#          9.13788108,   6.39727096,   2.81491316,   0.20860186,
#         13.03502145,   5.37840068,   2.78226884,   6.9830332 ,
#          9.75463363,   4.05599115,   3.13541809,   2.58170305,
#          5.20504965,  10.97731122,   5.9059593 ,   1.80073426,
#          8.89043554,   1.5932382 ,   3.09461976,   0.30868083,
#         10.62690977,   8.32390362,  12.9729912 ,   3.7052954 ,
#         13.15844058,   6.79431737,   2.01988476,  12.66793089,
#         11.32410174,   1.35952666,   1.1534719 ,  10.06010733,
#         12.76460594,  12.69205744,   6.31064321,  11.89859823,
#          8.13766009,  10.83677864,   4.62842226,   1.0520511 ,
#         12.45192237,   3.34414085,   7.48013136,   8.72377206,
#          3.95014091,  13.4092597 ,  10.02299015,   9.51894641,
#          5.307431  ,   5.78146675,  11.05465797,   7.25179397,
#          3.88948344,  10.66746853,   9.31124489,  11.63156262,
#          7.5100001 ,  10.79454397,   7.77883532,   5.49236216,
#          8.05118535,  11.77520303,   4.64493417,   3.83411555,
#         10.6987194 ,   9.92612905,   9.36132303,  10.09025788,
#          4.62565991,   9.44509912,  12.48455888,   2.94038437,
#         13.28631332,  10.77887034,   2.16702156,   1.03383361,
#          3.98953488,   8.10056499,   4.1121562 ,   0.38706578,
#          1.92496271,  12.71738088,  11.27715205,   4.50809448,
#          8.43124859,  12.16681314,   0.33939152,   9.37859662,
#          8.40585767,   8.58085714,   4.23714006,   8.37196147,
#          4.25380878,   1.89812875,   4.49468082,  10.95750048,
#          2.09151862,   6.05911105,  11.9838854 ,   6.74800216,
#          2.34356159,   5.15612686,   5.83166744,   6.25300348,
#          6.22081801,   5.10624997,   5.53704046,   9.99687684,
#         13.05927688,   9.68404944,   5.65248241,  12.74472582,
#         12.7864985 ,   7.23675802,  11.41400399,   5.99268959,
#          9.99245774,  10.76802898,   1.29974236,  11.40753166,
#         11.72993   ,  12.55541052,  10.93341315,   4.8705713 ,
#          8.41881688,   1.9725108 ,   8.30587714,  11.5746219 ,
#         12.15384522,  13.1052066 ,  10.25065572,  11.53393765,
#          4.07803126,  10.07671501,   6.93537353,   5.21477591,
#          2.2590934 ,   0.57795938,   4.66773202,   3.74585757,
#          4.84879359,   7.64581068,   7.71512192,   7.53639465,
#          6.6972684 ,   2.81331228,   9.23732744,  12.40824847,
#          6.93240583,  10.18558403,   6.09853908,   7.25058325,
#         10.8771143 ,  10.43751301,   2.37866794,   8.67674373,
#          3.77855044,   5.0145305 ,   8.37305333,   1.26187273,
#          8.67796007,   1.88594233,   0.54782119,   3.50952725,
#          6.27236375,  10.75785064,   5.48138215,   2.73576635,
#          1.68730148,   6.88004174,   0.73211233,   3.7039679 ,
#         10.49423469,   5.29021236,   2.40346012,   0.07893448,
#          1.60570409,  13.39841593,   5.40963849,   1.46035433,
#          7.75056911,   3.85840702,  11.99188765,   8.55523072,
#          8.65981979,   7.78938121,   5.42635827,   3.35186272,
#          4.14139871,   0.33142002,   3.39032968,   8.6087619 ,
#          9.22868227,   4.63768177,   3.54411637,   3.75196073,
#          7.8097186 ,  10.71015541,   0.07377058,  11.04351745,
#         10.38853967,   8.35998656,   1.01084566,   0.21712983,
#          6.69921498,   5.85765066,   1.91303067,   4.4757437 ,
#          6.42553473,   6.97451909,  10.924948  ,  10.12604525,
#          2.61496564,  10.64627856,  11.90470874,   9.79373873,
#          7.30048872,   0.25942099,   4.43745436,   2.24324406,
#          6.57382094,   4.6875663 ,  11.63351246,   8.78388428,
#         10.22291679,  10.2491341 ,   5.54759606,  11.21629059,
#          7.76534032,   0.54742297,  13.29802358,   5.45417025,
#          6.75188796,   2.91454169,   0.86647507,  10.87337824,
#         11.62106614,   9.87924163,   4.78568715,   3.15103101,
#         12.00096475,   9.74304876,   9.50663924,  12.74237832,
#         11.43635102,   5.84622491,   6.49994502,   2.45101151,
#          0.23104158,   5.23470461,  10.14788049,   1.07976646,
#         11.71549171,   3.048745  ,   8.78533532,   6.83778677,
#          6.24590698,   9.96174339,  12.26157818,  11.47629511,
#          8.09820503,   2.7852291 ,  11.88697765,   7.82751705,
#          0.65107103,  10.45116773,   7.89911365,   5.24628692,
#          0.22365512,   4.12824593,   3.05921696,   1.81585785,
#         11.52076509,   2.18159668,  12.70636099,  11.99824481,
#          7.25131377,   6.42760731,   5.21130467,   1.05095156,
#          5.71447845,   0.74382504,   1.58823149,   2.36540601,
#          2.54096448,   8.37128194,  12.37094579,   6.53022307,
#          4.24439892,   4.62774962,  11.88644023,  12.93042853,
#         13.00492218,   5.27409234,   5.20018379,   8.89103826,
#          6.3722013 ,  10.76412806,   6.61475033,  10.41837137,
#          1.85540673,  10.76062878,   0.67996214,   7.82643904,
#         10.03186152,   8.94070959,   6.19840708,   6.44417463,
#          8.83770324,   8.89877527,   7.23800935,   5.05214795,
#          2.53315882,   0.97605681,   0.18297571,   4.20792439,
#          3.31311917,   1.85664156,   4.38475116,   9.85393273,
#          7.03434548,   0.84122785,   3.80267826,   0.26283822,
#          6.09565892,   7.14788379,   3.80415051,   8.08417403,
#          3.27970481,   8.45857736,   7.41915176,  11.30526612,
#          6.17154483,  11.62201947,   1.0759209 ,   9.13126077,
#          6.49131829,   7.77761173,  11.06297799,   0.26024442,
#          5.72745735,   4.73665997,  11.51600087,   3.70420592,
#          8.57830285,   5.86328676,  10.71812535,   4.78826208,
#          7.17826544,   4.20574175,   0.02397678,   5.7555545 ,
#         12.85091473,   5.45208601,   1.00643089,   5.97817217,
#         10.98509337,   4.1728977 ,  10.03650451,   6.25234494,
#          4.60292069,   8.57065197,   3.61563092,  11.14805737,
#          4.56613291,   3.09974613,   2.37433039,   2.72223773,
#          6.34443933,  10.37940162,   8.66753331,   9.5196521 ,
#          7.16765014,   6.20674375,   6.99382213,   1.27259109,
#         11.06640349,   4.30218682,   6.85203589,   8.0981365 ,
#          6.05666374,   2.98686132,  11.72701337,   0.36306145,
#          9.42019717,   6.24515089,   5.21394906,   7.95692784,
#          5.43596522,   0.85665677,   8.90398296,  11.13664139,
#         13.30081132,   6.53346734,   3.80978375,   4.12568535,
#          9.90739664,   2.4602007 ,   5.19612899,  12.05899458,
#         12.23092133,   5.88737409,   2.34054189,  12.90316409,
#          0.70148093,  10.65060365,  13.0207986 ,  13.35467653,
#         12.9521953 ,   5.86041016,   8.39621954,   2.89759344,
#          7.14170738,  11.75462861,   5.6830738 ,  12.25589247,
#          2.81920378,   9.06987796,  11.08579193,  11.53723136,
#          9.34977762,   6.65084875,   7.33124476,  12.45134163,
#          6.16735833,   6.72688076,  11.15612322,   7.49882337,
#          0.24005359,   7.64775371,   8.44201975,   5.43145564,
#          4.26046532,  11.2655974 ,   2.80837856,   8.03986601,
#          5.32747253,   2.04676181,   4.27932646,   6.42507082,
#         12.03352406,   1.27523593,  11.81467395,  10.17321809,
#         13.21363496,  10.88274615,   8.60725432,   1.07195662,
#          2.61887657,   2.30830908,   1.23925991,   1.84403308,
#          4.63862125,   2.28977291,   0.40368103,  13.07848378,
#          1.4308857 ,  11.26963624,   8.91067163,   8.6496442 ,
#          0.56843897,   1.04087121,  10.91227651,   9.55867055,
#          4.21366902,   8.92883006,  10.86261264,  10.51070623,
#          9.03188154,   7.471622  ,   0.19100332,   8.60254159,
#          6.30579258,   9.20594484,   0.3850471 ,  11.55071524,
#          6.23733621,   1.97157603,   9.49231307,   5.26390941,
#         12.18778484,   2.40165692,   2.06207505,   6.67481298,
#          3.85597227,   4.12803473,   8.19259602,  12.72798419,
#          7.49495801,   4.08448981,   9.35778695,   1.42138957,
#          5.86112514,  12.2208573 ,   8.44885749,  10.51942456,
#          1.20980247,   5.89273608,   4.78473737,   5.71950113,
#          5.11485996,   9.1977289 ,   8.42672486,   0.23366237,
#         10.41100367,   2.84149847,   0.24358244,  12.78959182,
#         10.5760304 ,   5.11094315,  11.45266118,  10.55006086,
#          8.90404396,   6.46964004,  12.17607281,   3.38482517,
#          7.38342301,   3.84245674,   0.10823379,   7.72094492,
#         13.1694887 ,   7.78168794,   9.417449  ,  12.35443162,
#         13.39946263,  11.55755062,  12.32346912,   1.77763219,
#          0.31210261,   2.74508103,   7.26009091,   8.07226516,
#          8.88726719,   3.14028338,   3.59858181,   9.27105802,
#          5.36265596,  13.40501211,  11.44479526,   7.10919576,
#          8.96925404,  10.59876142,  10.54759465,  11.12816216,
#          7.86517417,   5.48745072,   6.44129528,  10.69273128,
#          2.98940727,   6.8750189 ,   5.41290571,   3.88676345,
#          3.30505246,   4.13383709,   1.33486948,   1.36419434,
#         12.23100002,   8.34646221,   4.34809142,   5.96665272,
#          5.18570229,   6.336289  ,   2.6548282 ,  12.27399978,
#          6.66304544,   7.72830201,  10.03197885,   7.48915105,
#          6.99231728,  12.31337699,   2.52317651,  12.86453084,
#         11.38652308,   8.93692607,   0.37501872,   0.31250209,
#          7.35152612,   3.82341769,  13.40090761,  10.94837571,
#          1.23784066,   4.24197454,   0.52606686,   8.25886999,
#          6.6799408 ,   1.9788422 ,  10.83144695,  11.61768523,
#          4.5858199 ,   0.12141768,   7.72981182,   3.9679601 ,
#          9.5163682 ,   9.90111495,  12.32104275,   2.21257789,
#          8.88527804,  11.00726155,  10.81157887,   0.81963954,
#          0.95949438,   8.7351277 ,   1.4300269 ,   3.0137703 ,
#          6.77740157,   5.78172715,   9.47645158,   0.08311247,
#          7.10181512,   7.17294439,   4.64221091,   6.87306124])

# %% [markdown]
# Ok it works.  Now let's try comparing two sites to see which is better suited to wind turbine placement.  Let's compare site 1 and site 3.

# %%
site1 = checkandconvert(x[1]) + 5*numpy.random.random(1000)
site3 = checkandconvert(x[2])

# %%
site1avg = numpy.average(site1)
site3avg = numpy.average(site3)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(11,8))
plt.plot(site1)
plt.plot(site3)

# %%
maxwindspeed = 12*numpy.ones(1000)

# %%
N = 12
window = numpy.ones(N)/N
site1smooth = numpy.convolve(site1,window,'same')
site3smooth = numpy.convolve(site3,window,'same')
plt.figure(figsize=(11,11))
plt.plot(site1smooth)
plt.plot(site3smooth)

plt.plot(maxwindspeed)
plt.plot(site1avg*numpy.ones(1000))
plt.plot(site3avg*numpy.ones(1000))

plt.ylabel('Wind Speed (m/s)')
plt.xlabel('Days')
plt.ylim(2,16)

plt.legend(['Site 1','Site 3','Max Allowable Wind Speed','Site 1 Average','Site 3 Average']);

# %% [raw]
# Please ignore the code below. It just loads a style.

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../styles/custom.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=Fenix' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'Fenix', serif;
#     }
#     h3{
# 		font-family: 'Fenix', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
# 	h4{
# 		font-family: 'Fenix', serif;
#        }
#     h5 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     div.text_cell_render{
#         font-family: 'Alegreya Sans',Computer Modern, "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;
#         line-height: 135%;
#         font-size: 120%;
#         width:600px;
#         margin-left:auto;
#         margin-right:auto;
#     }
#     .CodeMirror{
#             font-family: "Source Code Pro";
# 			font-size: 90%;
#     }
# /*    .prompt{
#         display: None;
#     }*/
#     .text_cell_render h1 {
#         font-weight: 200;
#         font-size: 50pt;
# 		line-height: 100%;
#         color:#CD2305;
#         margin-bottom: 0.5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#     .text_cell_render h5 {
#         font-weight: 300;
#         font-size: 16pt;
#         color: #CD2305;
#         font-style: italic;
#         margin-bottom: .5em;
#         margin-top: 0.5em;
#         display: block;
#     }
#
#     .warning{
#         color: rgb( 240, 20, 20 )
#         }
# </style>
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"]
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>
